# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv('Customer_Data.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# Gender             object
# Age               float64
# Annual Income     float64
# Total Spending    float64
# Interests          object
# dtype: object

# %%
df.count()
# Out:
# Unnamed: 0        1600
# Gender            1600
# Age               1598
# Annual Income     1596
# Total Spending    1600
# Interests         1600
# dtype: int64

# %%
# Dropping irrelevant columns
df = df.drop(['Unnamed: 0'], axis=1)
#df.head(5)
# Total number of rows and columns
df.shape
# Out:
# (1600, 5)

# %%
df.describe()
# Out:
#                Age  Annual Income  Total Spending
# count  1598.000000    1596.000000     1600.000000
# mean     37.895494     187.129699     2575.600781
# std      16.226009    5004.797654     1453.083432
# min      14.000000    -100.000000     -102.500000
# 25%      28.000000      39.000000     1383.750000
# 50%      35.000000      65.000000     2511.250000
# 75%      47.000000      81.000000     3843.750000
# max     350.000000  200000.000000     5176.250000

# %% [markdown]
# We can see that there are max age is 350 years and max income 200000000 (Customer’s Annual Income ($1000 USD) in dataset), which will probably cause issue in further analysis

# %%
# Finding the null values.
print(df.isnull().sum())
# Out:
# Gender            0
# Age               2
# Annual Income     4
# Total Spending    0
# Interests         0
# dtype: int64

# %%
# Dropping the missing values.
df = df.dropna() 
df.count()
# Out:
# Gender            1594
# Age               1594
# Annual Income     1594
# Total Spending    1594
# Interests         1594
# dtype: int64

# %%
# After dropping the values
print(df.isnull().sum())
# Out:
# Gender            0
# Age               0
# Annual Income     0
# Total Spending    0
# Interests         0
# dtype: int64

# %%
# Rows containing duplicate data
duplicate_rows_df = df[df.duplicated()]
print('number of duplicate rows: ', duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (4, 5)

# %%
#data incnsistency values
df[df['Age']>100]
# Out:
#      Gender    Age  Annual Income  Total Spending    Interests
# 5      male  250.0           21.0           820.0      Reading
# 500  female  350.0           75.0          1845.0  Photography

# %%
df[df['Annual Income']<0]
# Out:
#      Gender   Age  Annual Income  Total Spending Interests
# 940  female  58.0         -100.0         2408.75      Pets

# %%
df[df['Annual Income']>20000]
# Out:
#      Gender   Age  Annual Income  Total Spending Interests
# 1430   male  28.0       200000.0         4048.75     Music

# %%
#replace ages with correct ones 
df.Age = df.Age.replace({250.0: 25.0, 350.0: 35.0})

# Get names of indexes for which column Income has value
i = df[df['Annual Income'] < 0 ].index
# Delete these row indexes from dataFrame
df.drop(i, inplace=True)
# Get names of indexes for which column Income has value
j = df[df['Annual Income'] == 200000].index
# Delete these row indexes from dataFrame
df.drop(j, inplace=True)

# %%
df['Annual Income']=df['Annual Income']*1000

# %%
# Create a histogram of ages
df.hist('Age', bins=35);
plt.title('Distribution of Age');
plt.xlabel('Age');

# %% [markdown]
# The ages are mostly between 28 and 38. Recalling the describe() call results this makes sense. The average age was 37.5.
# There are less older customers, so this distribution is right-skewed because of its longer right tail.
# This could be because of the appeal of malls and the type of demographic that tends to shop there.

# %%
# See the distribution of gender to recognize different distributions
sns.countplot(x='Gender', data=df);
plt.title('Distribution of Gender')
# Out:
# Text(0.5, 1.0, 'Distribution of Gender')

# %% [markdown]
# There are slightly more women than men in this data set.
# They will perhaps be a significant element in customer segmentation efforts later.

# %%
#we can add detail to this by overlaying two histograms, creating one age histogram for each gender.
plt.hist('Age', data=df[df['Gender'] == 'male'], alpha=0.5, label='Male');
plt.hist('Age', data=df[df['Gender'] == 'female'], alpha=0.5, label='Female');
plt.title('Distribution of Age by Gender');
plt.xlabel('Age');
plt.legend();

# %%
ncount = len(df)
plt.figure(figsize=(8,8))
ax = sns.countplot(data=df, x = 'Interests')
ax.set_xticklabels(ax.get_xticklabels(), fontsize = 8, rotation=30, ha="right")
plt.tight_layout()
plt.show()
for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{:.2f}%'.format(100.*y/ncount), (x.mean(), y),ha='center', va='bottom')

# %%
fig = plt.figure(figsize = (10,10))
a1 = fig.add_subplot(2,2,1)
a2 = fig.add_subplot(2,2,2)
a3 = fig.add_subplot(2,2,3)
a1.boxplot(df['Age'])
a2.boxplot(df['Annual Income'])
a3.boxplot(df['Total Spending'])
plt.show()

# %%
# Histogram of income by gender
plt.hist('Annual Income', data=df[df['Gender'] == 'male'], alpha=0.5, label='Male');
plt.hist('Annual Income', data=df[df['Gender'] == 'female'], alpha=0.5, label='Female');
plt.title('Distribution of Income by Gender');
plt.xlabel('Income');
plt.legend();

# %% [markdown]
# The women and men in this data set make apx equal amount of money.

# %%
# Create data sets by gender to save time in the future since gender seems to significantly impact other variables
male_customers = df[df['Gender'] == 'male']
female_customers = df[df['Gender'] == 'female']

# Print the average total spending amount for men and women
print(male_customers['Total Spending'].mean())
print(female_customers['Total Spending'].mean())
# Out:
# 2554.9170918367345
# 2595.7998143564355

# %%
plt.figure(figsize=(5,5))
c= df.corr()
sns.heatmap(c,annot=True)
c
# Out:
#                      Age  Annual Income  Total Spending
# Age             1.000000      -0.023624       -0.371004
# Annual Income  -0.023624       1.000000        0.014862
# Total Spending -0.371004       0.014862        1.000000

# %% [markdown]
# There is somewhat strong correlation between Age and Total spending features.

# %%
sns.pairplot(df, diag_kind = 'kde', plot_kws={'alpha': 0.5})

# %%
sns.scatterplot('Age', 'Annual Income', hue='Gender', data=df)
plt.title('Age to Income, Colored by Gender')
# Out:
# Text(0.5, 1.0, 'Age to Income, Colored by Gender')

# %% [markdown]
# We can now see that slight positive correlation.

# %%
#Lets check  if there is a stronger correlation for men or women. 
#We check that out with two heat maps on the gender-specific data frames created earlier.
sns.heatmap(female_customers.corr(), annot=True);
plt.title('Correlation Heatmap - Female');

# %%
sns.heatmap(male_customers.corr(), annot=True);
plt.title('Correlation Heatmap - Male');

# %% [markdown]
# Age slightly strongly affects total spending for women in this case. Nothing else is really strongly correlated enough to say much of anything.

# %%
#Scatter of age to spending score for women, with a regression line and bootstrap interval about the line
sns.lmplot('Age', 'Total Spending', data=female_customers);
plt.title('Age to Total Spending amount, Female Only');

# %%
#Scatter of age to spending score for women, with a regression line and bootstrap interval about the line
sns.lmplot('Age', 'Total Spending', data=male_customers);
plt.title('Age to Total Spending amount, Male Only');

# %%
sns.scatterplot('Annual Income', 'Total Spending', hue='Gender', data=df);
plt.title('Annual Income to Total Spending, Colored by Gender');

# %% [markdown]
# There is some patterning here. Zero correlation though. But we can think of these as customer segments:<br>
# 1)Low income, low total spending<br>
# 2)Low income, high total spending<br>
# 3)Mid income, medium total spending<br>
# 4)High income, low totalspending<br>
# 5)High income, high total spending<br>

# %% [markdown]
# ## CLUSTERING

# %% [markdown]
# We will convert string values for Gender and Interests features into numerical to implement K-means algorithm

# %%
# creating a dict file  
gender = {'male': 0,'female': 1} 
# traversing through dataframe 
# Gender column and writing 
# values where key matches 
df.Gender = [gender[item] for item in df.Gender]

# %%
# creating a dict file 
interest = {'Cooking':1,'Exercise':2,'Travel':3,'Crafts':4,'Reading':5,'Strategic games':6,
            'Photography':7,'Hiking':8,'Gaming':9,'Camping':10,'Entertainment':11,'Sports':12,
            'Music':13,'Automobiles':14,'Yoga':15,'Art':16,'Technology':17,'Pets':18,'Gardening':19}
df.Interests = [interest[item] for item in df.Interests]

# %%
#We will arrive at the optimum number of clusters using the elbow method:from sklearn.cluster import KMeans
X = df.iloc[:,1:]
wcss = []
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))    
plt.grid()
plt.plot(range(1,11),wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("K Value")
plt.xticks(np.arange(1,11,1))
plt.ylabel("WCSS")
plt.show()

# %% [markdown]
# Based on the elbow plot, we could choose 4,5 or 6 clusters.
# Let us try both the number of clusters and visualize the clusters to decide on the final number of clusters.

# %%
#Fitting the k-means to the dataset with k=4
##Fitting kmeans to the dataset with k=4
km4=KMeans(n_clusters=4,init='k-means++', max_iter=300, n_init=10, random_state=0)
y_means = km4.fit_predict(X)

# %%
#Visualizing the clusters for k=4
km4 = KMeans(n_clusters=4)
clusters = km4.fit_predict(X)
df["label"] = clusters

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.Age[df.label == 0], df["Annual Income"][df.label == 0], df["Total Spending"][df.label == 0], c='blue', s=60)
ax.scatter(df.Age[df.label == 1], df["Annual Income"][df.label == 1], df["Total Spending"][df.label == 1], c='red', s=60)
ax.scatter(df.Age[df.label == 2], df["Annual Income"][df.label == 2], df["Total Spending"][df.label == 2], c='green', s=60)
ax.scatter(df.Age[df.label == 3], df["Annual Income"][df.label == 3], df["Total Spending"][df.label == 3], c='orange', s=60)
ax.view_init(30, 185)
plt.xlabel('Age')
plt.ylabel('Annual Income')
ax.set_zlabel('Total Spending')
plt.show()

# %%
#Visualizing the clusters for k=5
km5 = KMeans(n_clusters=5)
clusters = km5.fit_predict(X)
df["label"] = clusters

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.Age[df.label == 0], df["Annual Income"][df.label == 0], df["Total Spending"][df.label == 0], c='blue', s=60)
ax.scatter(df.Age[df.label == 1], df["Annual Income"][df.label == 1], df["Total Spending"][df.label == 1], c='red', s=60)
ax.scatter(df.Age[df.label == 2], df["Annual Income"][df.label == 2], df["Total Spending"][df.label == 2], c='green', s=60)
ax.scatter(df.Age[df.label == 3], df["Annual Income"][df.label == 3], df["Total Spending"][df.label == 3], c='orange', s=60)
ax.scatter(df.Age[df.label == 4], df["Annual Income"][df.label == 4], df["Total Spending"][df.label == 4], c='purple', s=60)
ax.view_init(30, 185)
plt.xlabel('Age')
plt.ylabel('Annual Income')
ax.set_zlabel('Total Spending')
plt.show()

# %%
#Visualizing the clusters for k=6
km6 = KMeans(n_clusters=6)
clusters = km6.fit_predict(X)
df["label"] = clusters

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.Age[df.label == 0], df["Annual Income"][df.label == 0], df["Total Spending"][df.label == 0], c='blue', s=60)
ax.scatter(df.Age[df.label == 1], df["Annual Income"][df.label == 1], df["Total Spending"][df.label == 1], c='red', s=60)
ax.scatter(df.Age[df.label == 2], df["Annual Income"][df.label == 2], df["Total Spending"][df.label == 2], c='green', s=60)
ax.scatter(df.Age[df.label == 3], df["Annual Income"][df.label == 3], df["Total Spending"][df.label == 3], c='orange', s=60)
ax.scatter(df.Age[df.label == 4], df["Annual Income"][df.label == 4], df["Total Spending"][df.label == 4], c='yellow', s=60)
ax.scatter(df.Age[df.label == 5], df["Annual Income"][df.label == 5], df["Total Spending"][df.label == 5], c='pink', s=60)
ax.view_init(30, 185)
plt.xlabel('Age')
plt.ylabel('Annual Income')
ax.set_zlabel('Total Spending')
plt.show()

# %%
#age, total spending and interests
km0 = KMeans(n_clusters=5)
clusters = km0.fit_predict(X)
df["label"] = clusters

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.Age[df.label == 0], df["Total Spending"][df.label == 0], df.Interests[df.label == 0], c='blue', s=60)
ax.scatter(df.Age[df.label == 1], df["Total Spending"][df.label == 1], df.Interests[df.label == 1], c='red', s=60)
ax.scatter(df.Age[df.label == 2], df["Total Spending"][df.label == 2], df.Interests[df.label == 2], c='green', s=60)
ax.scatter(df.Age[df.label == 3], df["Total Spending"][df.label == 3], df.Interests[df.label == 3], c='orange', s=60)
ax.scatter(df.Age[df.label == 4], df["Total Spending"][df.label == 4], df.Interests[df.label == 4], c='purple', s=60)
ax.view_init(30, 185)
plt.xlabel('Age')
plt.ylabel('Total Spending')
ax.set_zlabel('Interests')
plt.show()

# %%
#annual income and total spending
km00 = KMeans(n_clusters=5)
clusters = km00.fit_predict(X)
df["label"] = clusters

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
ax.scatter(df["Annual Income"][df.label == 0], df["Total Spending"][df.label == 0], c='blue', s=60)
ax.scatter(df["Annual Income"][df.label == 1], df["Total Spending"][df.label == 1], c='red', s=60)
ax.scatter(df["Annual Income"][df.label == 2], df["Total Spending"][df.label == 2], c='green', s=60)
ax.scatter(df["Annual Income"][df.label == 3], df["Total Spending"][df.label == 3], c='orange', s=60)
ax.scatter(df["Annual Income"][df.label == 4], df["Total Spending"][df.label == 4], c='purple', s=60)
plt.xlabel('Annual Income')
plt.ylabel('Total Spending')
plt.show()

# %%
#interests and total spending
km1 = KMeans(n_clusters=5)
clusters = km1.fit_predict(X)
df["label"] = clusters

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
ax.scatter(df["Total Spending"][df.label == 0], df.Interests[df.label == 0], c='blue', s=60)
ax.scatter(df["Total Spending"][df.label == 1], df.Interests[df.label == 1], c='red', s=60)
ax.scatter(df["Total Spending"][df.label == 2], df.Interests[df.label == 2], c='green', s=60)
ax.scatter(df["Total Spending"][df.label == 3], df.Interests[df.label == 3], c='orange', s=60)
ax.scatter( df["Total Spending"][df.label == 4], df.Interests[df.label == 4], c='purple', s=60)
plt.ylabel('Interests')
plt.xlabel('Total Spending')
plt.show()

# %%
#interests and total spending
km1 = KMeans(n_clusters=5)
clusters = km1.fit_predict(X)
df["label"] = clusters

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
ax.scatter(df["Total Spending"][df.label == 0], df.Interests[df.label == 0], c='blue', s=60)
ax.scatter(df["Total Spending"][df.label == 1], df.Interests[df.label == 1], c='red', s=60)
ax.scatter(df["Total Spending"][df.label == 2], df.Interests[df.label == 2], c='green', s=60)
ax.scatter(df["Total Spending"][df.label == 3], df.Interests[df.label == 3], c='orange', s=60)
ax.scatter( df["Total Spending"][df.label == 4], df.Interests[df.label == 4], c='purple', s=60)
plt.ylabel('Interests')
plt.xlabel('Total Spending')
plt.show()
